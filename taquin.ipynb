# %%
from taquin import Board

board = Board(5,10,10,30)
#board = Board(4,4,13,10)

# %%
board()
# Out:
# ...
# Label(value='')
# FigureWidget({
#     'data': [],
#     'layout': {'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0]},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0]}}
# })

# %%
board.run()
# Out:
# BROADCAST (turn 0): self 9 to (2, 2) priority 4BROADCAST (turn 0): self 16 to (3, 0) priority 2
# BROADCAST (turn 0): self 2 to (1, 1) priority 3
# BROADCAST (turn 0): self 25 to (0, 4) priority 6
# BROADCAST (turn 0): self 14 to (3, 3) priority 3
# BROADCAST (turn 0): self 7 to (1, 3) priority 4
# BROADCAST (turn 0): self 1 to (1, 0) priority 3
# BROADCAST (turn 0): self 22 to (1, 1) priority 5
# BROADCAST (turn 0): self 15 to (2, 4) priority 2
#
# BROADCAST (turn 0): self 19 to (1, 3) priority 4
# BROADCAST (turn 0): self 7 to (2, 4) priority 6
# BROADCAST (turn 0): self 15 to (2, 4) priority 1
# BROADCAST (turn 0): self 15 to (2, 3) priority 10
# BROADCAST (turn 0): self 2 to (2, 0) priority 5
# CONFLICTS SOLVED in recursive (turn 0): self 2, (current, next) : [((1, 2), (1, 3)), ((2, 1), (2, 0)), ((4, 3), (3, 3)), ((3, 1), (3, 0)), ((0, 3), (0, 4)), ((2, 0), (1, 0)), ((1, 4), (2, 4)), ((2, 3), (2, 3)), ((1, 0), (1, 1)), ((3, 2), (2, 2))]
# ...
